# %%
import pandas as pd

# %%
df = pd.read_json("data/cable_machine.json")

df
# Out:
#      foundNoOffers                                                url  \
# 0              1.0               https://www.amazon.com/dp/B09HL3JQ7Q
# 1              NaN  https://www.amazon.com/gp/product/B09HL3JQ7Q?s...
# 2              1.0               https://www.amazon.com/dp/B0C6XWMXYP
# 3              NaN  https://www.amazon.com/gp/product/B0C6XWMXYP?s...
# 4              NaN  https://www.amazon.com/gp/product/B078HRLFHX?s...
# ..             ...                                                ...
# 225            NaN  https://www.amazon.com/gp/product/B0DPLC8ZCD?s...
# 226            1.0               https://www.amazon.com/dp/B0CQ88XFHT
# 227            NaN  https://www.amazon.com/gp/product/B0CQ88XFHT?s...
# 228            1.0               https://www.amazon.com/dp/B09SJZJHLF
# 229            NaN  https://www.amazon.com/gp/product/B09SJZJHLF?s...
#
#                          shippingPrice condition  position  \
# 0                                 None      None       NaN
# ...

# %%
import json

data = json.load("data/cable_machine.json")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 3
#       1 import json
# ----> 3 data = json.load("data/cable_machine.json")
#
# File /opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/json/__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
# ...
